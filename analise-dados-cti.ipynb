# %%
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl as px

# %%
# Ao executar qualquer um dos ETL deste projeto, não é devido considerar nenhuma das datas além de data_inicio e data_vencimento, isso porque 
# as outras datas são de criação, atualização ou exclusão do registro, e não de quando o evento ocorreu. Vale relembrar que o trello conectado no ETL
#traz dados  criados manualmente e os dados de criação, data_last_activity e data_last_update são de quando o registro foi criado, atualizado ou excluído,
#e não de quando o evento ocorre que foi copiado do trello fornecido da CTI. Portanto, as datas a serem consideradas para análise são data_inicio e data_vencimento.

# %%
df = pd.read_excel("dados-reais-cti.xlsx")
df.head()
# Out:
#                 Nome-Card         Data-Inicio            Data-Fim  \
# 0             Alinhamento 2026-03-02 08:00:00 2026-03-03 14:47:00
# 1                Kick-Off 2026-03-03 08:00:00 2026-03-04 14:47:00
# 2          ConfiguraÃ§Ã£o 2026-03-03 08:00:00 2026-03-04 14:47:00
# 3            Double Check                 NaT 2026-03-04 14:47:00
# 4  Encaminhar dispositivo 2026-03-05 08:00:00 2026-03-09 14:47:00
#
#       Tempo-Total  Tempo-Trabalho  Atrasado
# 0 1 days 06:47:00 0 days 16:47:00     False
# 1 1 days 06:47:00 0 days 16:47:00     False
# 2 1 days 06:47:00 0 days 16:47:00     False
# 3             NaT             NaT     False
# 4 4 days 06:47:00 1 days 02:47:00      True

# %%
#
plt.boxplot(df['Tempo-Total'])
plt.title('Distribuição do Lead Time')
plt.show()
